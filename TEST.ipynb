# %% [markdown]
# <a href="https://colab.research.google.com/github/wego-special/test00/blob/main/TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
y = numpy.random.normal(10.0, 2.0, 100000)

plt.scatter(x, y)
plt.show()
